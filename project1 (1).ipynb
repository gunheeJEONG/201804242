# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\jks04\\OneDrive\\바탕 화면\\download'

# %%
import pandas as pd
df1 = pd.read_csv('project_files/광진구_공영주차장3.csv', encoding='UTF8')

# %%
df1.head()
# Out:
#      운영개시일    동명       시설명            위치         위도          경도      부지면적  \
# 0  1998-03  중곡2동       장신구   중곡2동 133-10  37.560348  127.085753       531
# 1  1999-06  중곡2동    중곡동복개천  중곡2동 150-196  37.556301  127.084047       NaN
# 2  2009-04  중곡3동  중곡3동마을공원    중곡3동 195-1  37.569368  127.084663    3038.3
# 3  2010-01  중곡3동    중곡체육센터    중곡3동 168-8  37.566771  127.083415  3,690.00
# 4  1996-01  중곡4동     신성시장길   중곡4동 453 일대  37.559053  127.089412       NaN
#
#    주차면수 소계  주차면수 노상  주차면수 노외  거주자   공영  급지 주차요금 5분당 주차요금 주간 주차요금 야간 주차요금 종일  \
# 0       22      0.0     22.0    O  NaN   5      NaN     4만원     3만원     5만원
# 1       78     78.0      0.0  NaN    O   2     200원     NaN     NaN    10만원
# 2      162      NaN    162.0    O    O   5      75원     4만원     3만원     5만원
# 3        6      NaN      6.0    O  NaN   5      NaN     4만원     3만원     5만원
# 4       33     33.0      NaN  NaN    O   2     250원     NaN     NaN    10만원
#
#    시설규모             비고
# 0   NaN            시유지
# ...

# %%
df_pp = df1[['동명','위도','경도','시설명']]

# %%
df_pp.head(20) #광진구 공영주차장
# Out:
#       동명         위도          경도               시설명
# 0   중곡2동  37.560348  127.085753               장신구
# 1   중곡2동  37.556301  127.084047            중곡동복개천
# 2   중곡3동  37.569368  127.084663          중곡3동마을공원
# 3   중곡3동  37.566771  127.083415            중곡체육센터
# 4   중곡4동  37.559053  127.089412             신성시장길
# 5   중곡4동  37.559053  127.089412               새오름
# 6   중곡4동  37.559053  127.089412              용마산남
# 7   중곡4동  37.559053  127.089412            긴고랑길공영
# 8   중곡4동  37.559053  127.089412               해오름
# 9   중곡4동  37.559053  127.089412  뻥튀기골주차장(용마공원주차장)
# 10  중곡4동  37.576211  127.082825     중곡4동 599-6 인근
# 11  중곡4동  37.559053  127.089412             한림대부지
# 12    능동  37.554043  127.080240              능동공영
# 13    능동  37.553205  127.079584              능동공동
# 14  구의1동  37.546730  127.085756           구의1동 공영
# 15  구의1동  37.538284  127.087847              구의번영
# 16  구의2동  37.544262  127.089008        구의2동 주택가공동
# 17  구의2동  37.553119  127.092885              광문학당
# ...

# %%
df_pp.value_counts('동명')
# Out:
# 동명
# 중곡4동    8
# 광장동     3
# 구의2동    3
# 구의3동    3
# 화양동     3
# 구의1동    2
# 군자동     2
# 능동      2
# 자양4동    2
# 중곡2동    2
# 중곡3동    2
# 자양1동    1
# 자양2동    1
# 자양3동    1
# dtype: int64

# %%
df_pp_count = df_pp['동명'].replace(['중곡4동','중곡2동','중곡3동'],'중곡동').replace(['구의1동','구의2동','구의3동'], '구의동').replace(['자양1동','자양2동','자양3동','자양4동'], '자양동')

# %%
df_pp_count.value_counts() #상세동 통합
# Out:
# 중곡동    12
# 구의동     8
# 자양동     5
# 광장동     3
# 화양동     3
# 능동      2
# 군자동     2
# Name: 동명, dtype: int64

# %%
df_pp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   동명      35 non-null     object
#  1   위도      35 non-null     float64
#  2   경도      35 non-null     float64
#  3   시설명     35 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 1.2+ KB

# %%
df2 = pd.read_csv('project_files/광진구_주정차단속.csv',encoding='cp949')

# %%
df2.describe().T
# Out:
#         count          mean          std     min      25%      50%      75%  \
# 과태료  503300.0  36689.576793  9841.538616  4000.0  32000.0  32000.0  40000.0
#
#           max
# 과태료  130000.0

# %%
df2.head(10)
# Out:
#                단속일시    과태료 단속지역         단속장소         위반내용  견인지시  단속구분
# 0  2015-01-01 06:44  32000  화양동        119-4        주정차금지  견인처리   PDA
# 1  2015-01-01 07:01  40000  화양동    건대입구1번출구앞  32조내지 34조위반   미견인  CCTV
# 2  2015-01-01 07:24  40000  구의동  동서울터미널 주차장앞  32조내지 34조위반   미견인  CCTV
# 3  2015-01-01 08:00  40000  화양동    건대입구1번출구앞  32조내지 34조위반   미견인  CCTV
# 4  2015-01-01 08:15  32000  화양동    건대입구1번출구앞  32조내지 34조위반   미견인  CCTV
# 5  2015-01-01 08:17  32000  화양동    건대입구1번출구앞  32조내지 34조위반   미견인  CCTV
# 6  2015-01-01 08:25  40000  구의동  동서울터미널 주차장앞  32조내지 34조위반   미견인  CCTV
# 7  2015-01-01 08:29  40000  구의동  리젠트오피스텔 건너편  32조내지 34조위반   미견인  CCTV
# 8  2015-01-01 08:35  40000  구의동  동서울터미널 주차장앞  32조내지 34조위반   미견인  CCTV
# 9  2015-01-01 08:36  50000  구의동      강변역1번출구  32조내지 34조위반   미견인  CCTV

# %%
df_crackdown = df2[['단속일시','단속지역','단속장소','단속구분']] # 광진구 주차단속 내역

# %%
df_crackdown.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503300 entries, 0 to 503299
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   단속일시    503300 non-null  object
#  1   단속지역    503300 non-null  object
#  2   단속장소    503294 non-null  object
#  3   단속구분    503300 non-null  object
# dtypes: object(4)
# memory usage: 15.4+ MB

# %%
df_crackdown.head(10)
# Out:
#                단속일시 단속지역         단속장소  단속구분
# 0  2015-01-01 06:44  화양동        119-4   PDA
# 1  2015-01-01 07:01  화양동    건대입구1번출구앞  CCTV
# 2  2015-01-01 07:24  구의동  동서울터미널 주차장앞  CCTV
# 3  2015-01-01 08:00  화양동    건대입구1번출구앞  CCTV
# 4  2015-01-01 08:15  화양동    건대입구1번출구앞  CCTV
# 5  2015-01-01 08:17  화양동    건대입구1번출구앞  CCTV
# 6  2015-01-01 08:25  구의동  동서울터미널 주차장앞  CCTV
# 7  2015-01-01 08:29  구의동  리젠트오피스텔 건너편  CCTV
# 8  2015-01-01 08:35  구의동  동서울터미널 주차장앞  CCTV
# 9  2015-01-01 08:36  구의동      강변역1번출구  CCTV

# %%
pd.crosstab(df_crackdown['단속지역'], df_crackdown['단속구분'])
# Out:
# 단속구분       CCTV    PDA  경찰서  고정형CCTV  버스장착형CCTV  생활불편앱(행안부)  소방서  스마트앱(서울시)  \
# 단속지역
# 강변북로          0     25    0        0          0           3    0          0
# 강변역로          0     53    0        0          0          13    0          1
# 강변역로2길        0      4    0        0          0           0    0          0
# 강변역로4길        0    226    0        0          0           1    0          0
# 광나루로          0   2004    0        0          0          48    0          3
# ...         ...    ...  ...      ...        ...         ...  ...        ...
# 천호대로138길      0    206    0        0          0           0    0          0
# 천호대로140길      0      5    0        0          0           0    0          0
# 천호대로141길      0     32    0        0          0           0    0          0
# 천호대로143길      0     10    0        0          0           0    0          0
# 화양동       18542  19869    0     5075          0          65    0        511
#
# 단속구분      시민신고제웹  안전신문고(행안부)  일반  주행형CCTV
# 단속지역
# ...

# %%
plt.rcParams['font.family'] = 'NanumGothic'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 plt.rcParams['font.family'] = 'NanumGothic'
#
# NameError: name 'plt' is not defined

# %%
# !pip uninstall -y matplotlib
# !pip install matplotlib

# %%
import matplotlib.font_manager as fm
fm._rebuild()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# matplotlib에서 사용 가능한 폰트 경로 출력
fm._rebuild()
for font in fm.fontManager.ttflist:
    print(font.fname)

# %%
import matplotlib.font_manager as fm

print(fm.get_fontconfig_fonts())

# %%
import matplotlib.font_manager as fm

# 설치된 폰트 출력
font_list = [font.name for font in fm.fontManager.ttflist]
font_list

# %%
# !pip uninstall matplotlib
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm


# 나눔글꼴 경로 설정
font_path = 'nanum-gothic/NanumGothic.ttf'
# 폰트 설정
font_prop = fm.FontProperties(fname=font_path)


# 변수에 교차표 저장
ct = pd.crosstab(df_crackdown['단속지역'], df_crackdown['단속구분'])

# 막대 그래프로 시각화
ct.plot(kind='bar', figsize=(10, 6))
plt.title('Crackdown Results by Region')
plt.xlabel('Region')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt

# 변수에 교차표 저장
ct = pd.crosstab(df_crackdown['단속지역'], df_crackdown['단속구분'])

# 막대 그래프로 시각화
ct.plot(kind='bar', figsize=(10, 6))
plt.title('단속 결과 지역별 통계', fontfamily='NanumGothic')
plt.xlabel('지역', fontfamily='NanumGothic')
plt.ylabel('건수', fontfamily='NanumGothic')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 나눔글꼴 경로 설정
font_path = 'nanum-gothic/NanumGothic.ttf'
# 폰트 설정
font_prop = fm.FontProperties(fname=font_path)

# 변수에 교차표 저장
ct = pd.crosstab(df_crackdown['단속지역'], df_crackdown['단속구분'])

# 막대 그래프로 시각화
ct.plot(kind='bar', figsize=(10, 6))
plt.title('단속 결과 지역별 통계', fontproperties=font_prop)
plt.xlabel('지역', fontproperties=font_prop)
plt.ylabel('건수', fontproperties=font_prop)
plt.show()

# %%
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
# 현재 작업 디렉토리에 있는 'nanum-gothic' 폴더에 있는 'NanumGothic.ttf' 폰트를 사용
font_path = 'C:/Users/jks04/OneDrive/desktop/download/nanum-gothic/NanumGothic.ttf'
font_prop = fm.FontProperties(fname=font_path)
ct.plot(kind='bar', figsize=(10, 6))
plt.title('단속 결과 지역별 통계', fontproperties=font_prop)
plt.xlabel('지역', fontproperties=font_prop)
plt.ylabel('건수', fontproperties=font_prop)
plt.show()

# %%
df_crackdown.value_counts('단속지역').head(50)

# %%
df_crackdown.value_counts('단속구분')

# %%
df2.info()

# %%
df3 = pd.read_csv('project_files/광진구_CCTV.csv',encoding='euc-kr')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   고정형CCTV지번주소  53 non-null     object
#  1   위도           53 non-null     float64
#  2   경도           53 non-null     float64
#  3   자치구          53 non-null     object
#  4   단속지점명        53 non-null     object
#  5   현장구분         53 non-null     object
# dtypes: float64(2), object(4)
# memory usage: 2.6+ KB

# %%
df3.tail(20)
# Out:
#           고정형CCTV지번주소         위도          경도  자치구                 단속지점명  \
# 33   서울 광진구 중곡동 231-2  37.565014  127.080397  광진구             신성그랜드타워 앞
# 34   서울 광진구 자양동 662-2  37.531472  127.083548  광진구              성자초등학교 옆
# 35  서울 광진구 자양동 679-30  37.532018  127.085371  광진구       한국보건의료인 국가시험원 앞
# 36   서울 광진구 중곡동 168-8  37.567767  127.084713  광진구            중곡문화체육센터 앞
# 37     서울 광진구 광장동 565  37.541929  127.099670  광진구        광장 힐스테이 상가 건너편
# 38   서울 광진구 자양동 239-1  37.536615  127.062808  광진구                 올포유 앞
# 39  서울 광진구 구의동 253-15  37.544137  127.084627  광진구          구의동 대림바스플랜 앞
# 40  서울 광진구 구의동 252-16  37.538247  127.083852  광진구            구의동 웰츠타워 앞
# 41    서울 광진구 구의동 17-1  37.554630  127.096635  광진구            구의동 금성빌라 앞
# 42     서울 광진구 자양동 855  37.533363  127.068534  광진구            이튼타워리버3차 앞
# 43   서울 광진구 군자동 374-4  37.547781  127.071974  광진구                  광진광장
# 44  서울 광진구 자양동 627-21  37.535226  127.084067  광진구           자양동 동제한의원 앞
# ...

# %%
df_CCTV = df3[['고정형CCTV지번주소','위도','경도','단속지점명']]

# %%
df_CCTV['고정형CCTV지번주소'] = df_CCTV['고정형CCTV지번주소'].str.replace('.*광장.*', '광장동')
df_CCTV['고정형CCTV지번주소'] = df_CCTV['고정형CCTV지번주소'].str.replace('.*구의.*', '구의동')
df_CCTV['고정형CCTV지번주소'] = df_CCTV['고정형CCTV지번주소'].str.replace('.*능동.*', '능동')
df_CCTV['고정형CCTV지번주소'] = df_CCTV['고정형CCTV지번주소'].str.replace('.*자양.*', '자양동')
df_CCTV['고정형CCTV지번주소'] = df_CCTV['고정형CCTV지번주소'].str.replace('.*군자.*', '군자동') 
df_CCTV['고정형CCTV지번주소'] = df_CCTV['고정형CCTV지번주소'].str.replace('.*중곡.*', '중곡동')
df_CCTV['고정형CCTV지번주소'] = df_CCTV['고정형CCTV지번주소'].str.replace('.*화양.*', '화양동')    

df_CCTV.value_counts('고정형CCTV지번주소')
# Out:
# C:\Users\jks04\AppData\Local\Temp\ipykernel_15064\1396824333.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_CCTV['고정형CCTV지번주소'] = df_CCTV['고정형CCTV지번주소'].str.replace('.*광장.*', '광장동')
# C:\Users\jks04\AppData\Local\Temp\ipykernel_15064\1396824333.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_CCTV['고정형CCTV지번주소'] = df_CCTV['고정형CCTV지번주소'].str.replace('.*광장.*', '광장동')
# C:\Users\jks04\AppData\Local\Temp\ipykernel_15064\1396824333.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_CCTV['고정형CCTV지번주소'] = df_CCTV['고정형CCTV지번주소'].str.replace('.*구의.*', '구의동')
# ...

# %%
import folium
m = folium.Map(location=[37.546730
,127.085756],  
               zoom_start=13.5)


latitude = df_CCTV["위도"]
longitude = df_CCTV["경도"]

latitude1 = df_pp["위도"]
longitude2 = df_pp["경도"]



# 원형 마커를 생성하고 맵에 추가
for lat, lon in zip(latitude, longitude):
    folium.CircleMarker([lat, lon], radius=5, color='blue', fill_color='blue').add_to(m)
for lat, lon in zip(latitude1, longitude2):
    folium.CircleMarker([lat, lon], radius=5, color='green', fill_color='green').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
m = folium.Map(location=[37.546730
,127.085756],  
               zoom_start=13.5)

for index, row in df_CCTV.iterrows():
    lat = row['위도']
    long = row['경도']
    popup = row['단속지점명'] # 마커 클릭시 나오는 팝업 메시지 설정
    marker = folium.Marker([lat, long], popup=popup)
    marker.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
pip install geopy

# %%
df_pp.head()
# Out:
#      동명         위도          경도       시설명
# 0  중곡2동  37.560348  127.085753       장신구
# 1  중곡2동  37.556301  127.084047    중곡동복개천
# 2  중곡3동  37.569368  127.084663  중곡3동마을공원
# 3  중곡3동  37.566771  127.083415    중곡체육센터
# 4  중곡4동  37.559053  127.089412     신성시장길

# %%
df_parking = pd.read_csv('project_files/광진구_공영주차장2.csv',encoding='cp949')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df_parking = pd.read_csv('project_files/광진구_공영주차장2.csv',encoding='cp949')
#
# File D:\download\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File D:\download\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df_parking.head()

# %%
df_spot = df_parking[['시설명','위도','경도']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df_spot = df_parking[['시설명','위도','경도']]
#
# NameError: name 'df_parking' is not defined

# %%
df_spot.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df_spot.head(10)
#
# NameError: name 'df_spot' is not defined
